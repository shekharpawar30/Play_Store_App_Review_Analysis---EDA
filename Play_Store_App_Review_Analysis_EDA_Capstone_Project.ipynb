# %% [markdown]
# <a href="https://colab.research.google.com/github/shekharpawar30/Play-Store-App-Review-Analysis/blob/main/Play_Store_App_Review_Analysis_EDA_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**  - **Play Store App Review Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - shekhar pawar (Individual)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# * Google Play Store is an online store where people go to find their favourite apps,games,movies,TV shows,Books and many more. It provides 2million apps and games to billion of people around the world
#
# * Basically we have two data sets to Analyse 1) Play Store data.csv & 2)User Review.csv
#
# * we have to analyse our data and help our developers that they can enter in this market with their apps
#
# * In this exploratory data analysis project we have look insight of the data and make sure that we get as much detailed to analyse data.
#
# * The main objective of this exploratory data analysis project is to recognize customer need what kind of app they prefer most and help developers to popularize their app on play store that their app get famous

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Google Play Store is one of the top app markets in the world, and it is quite popular among millions of people. As the app store market is growing, the demand for developers is also growing. The Play Store allows users to install different kinds of apps as per their interests and have access to rate and comment on the apps as per their experiences, which is called a review.
#
# To make a successful and engaging app, developers should have knowledge of the users choices and preferences for features like the app's size, price, Android version,when it was last updated, etc.
#
# Before developing the apps, developers should also know the user sentiment of other apps that have similar features to the future app.
#
# Two datasets are provided for the analysis of users choice and sentiment: one is basic information about the apps, and the other is about users reviews and sentiments about particular apps. Both datasets need to be examined in order to identify the important factors that influence app engagement and success.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#reading dataset
path = "/content/drive/MyDrive/capstone projects/"
df1 = pd.read_csv(path + "Play Store Data.csv")
df2 = pd.read_csv(path +  "User Reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
df1['App'].value_counts()
# Out:
# App
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: count, Length: 9660, dtype: int64

# %%
# Inspecting the duplicates values.
df1[df1['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
# 1701  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# ...

# %% [markdown]
# Yes, there are duplicates present in the 'App' column. We will handle them in the data wrangling process.

# %%
df1[df1.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %% [markdown]
# it consist of 483 instances of duplicated rows.

# %%
# Missing Values/Null Values Count
missing_values=df1[['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
       'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
       'Android Ver']].isnull().sum()
missing_values
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values

plt.figure(figsize=(10, 6))
missing_values.plot(kind='bar', color='skyblue')
plt.title('Missing Values Count by Variable')
plt.xlabel('Variables')
plt.ylabel('Missing Values Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# To gain insights into your dataset, we have performed various preliminary analyses. Here's what we've learned about the dataset based on the operations performed:
#
# 1. **Data Types**: The dataset contains a mix of numeric and categorical variables.
# 2. **Variable Names**: The dataset includes variables such as 'App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', and 'Android Ver'.
# 3. **Missing Values**: We've identified missing values in the 'Rating', 'Type', 'Content Rating', 'Current Ver', and 'Android Ver' variables.
# 4. **Duplicate Values**: We haven't yet examined duplicate values, but we're aware that they exist in the 'App' column.
# 5. **Data Distribution**: We haven't analyzed the distribution of numeric variables or the frequency distribution of categorical variables yet.
# 6. **Data Quality**: We've observed missing values, which may need to be addressed during data cleaning. Additionally, the presence of duplicates in the 'App' column may require further investigation.
#
# Overall, we have gained a preliminary understanding of the dataset, but further exploration and analysis are needed to fully understand its characteristics, quality, and potential insights it may offer.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns.tolist()
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
# Dataset Describe
df1.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * App - Name of an application
#
# * Category - App Category
#
# * Rating - App Rating from the user
#
# * Review - App Review
#
# * Size - App Size
#
# * Installs - Installations Information
#
# * Type - App Type (Free /Paid)
#
# * Price - App Price
#
# * Content Rating -Age Restriction
#
# * Current ver - Current version of the app available on Play Store
#
# * Android Ver - Minimum required Android Version

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df1.columns.tolist():
  print("No. of unique values in ",i,"is",df1[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %% [markdown]
# This list of unique values for variables may not be entirely accurate, as it includes null values. These null values have not been removed, thus they are being counted as distinct values for the respective variables

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ###Outliers

# %%
#Checking for outlier by plotting boxplot
df1.boxplot();

# %%
#Outlier present in Rating column
df1[df1['Rating']>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#Removing outlier
df1.drop([10472], inplace=True)

# %%
df1[10470:10475]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
#
#           Installs  Type Price Content Rating           Genres  \
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
# 10475      50,000+  Free     0       Everyone            Tools
#
#             Last Updated Current Ver   Android Ver
# 10470  February 10, 2017         0.1    2.3 and up
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# ...

# %%
#After Removing Outlier
df1.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ###Looking for and handling NaN/Null/Missing Values

# %%
#Getting the number of null values present in each column
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
#replacing NaN values present in rating column with Median
df1['Rating'].fillna(df1['Rating'].median(), inplace=True)

# %%
#Check for null values
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
#replacing NaN values present in Categorical column with mode value of that particular column
df1['Type'].fillna(str(df1['Type'].mode().values[0]), inplace = True)
df1['Current Ver'].fillna(str(df1['Current Ver'].mode().values[0]), inplace=True)
df1['Android Ver'].fillna(str(df1['Android Ver'].mode().values[0]), inplace = True)

# %%
#After replacing NaN Values
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# Now, here we can see that there are no null values in the DataFrame

# %% [markdown]
# ###converting datatype of the Columns into appropriate format

# %%
#checking datatype of the Columns
df1.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
#  it's clear that some columns have numbers, but they're marked as 'Object' instead of numbers like integers or decimals. To analyze the data properly, we need to change these columns to have the right data type, either whole numbers or decimal numbers.

# %%
#Coverting 'Price', 'Reviews', and 'Installs' into Numerical values
df1['Price'] = df1['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
df1['Price'] = df1['Price'].apply(lambda x: float(x))
df1['Reviews'] = df1['Reviews'].apply(lambda x: float(x))

# %%
#Converting the datatype of 'Installs' column to Float
df1['Installs'] = df1['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x))
df1['Installs'] = df1['Installs'].apply(lambda x: str(x).replace(',' , '') if ',' in str(x) else str(x))
df1['Installs'] = df1['Installs'].apply(lambda x: float(x))

# %% [markdown]
# Installs: The value of installs is in “string” format. It contains numerical values with commas. It should be removed. And also, the ‘+’ sign should be removed from the end of each string.

# %%
#The "Last Updated" column is currently in 'object' format, but it contains date values. Therefore,
#it should be converted to the 'datetime' format.
df1['Last Updated']= pd.to_datetime(df1['Last Updated'])

# %%
#Checking the type of value present in size column
type(df1['Size'][0])
# Out:
# str

# %%
#check unique values of Size column
df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# Size: The size of the app is in “string” format. We need to convert it into a numeric value. If the size is “10M”, then ‘M’ needs to be removed to get the numeric value of ‘10’. If the size is “512k”, which depicts app size in kilobytes, the first ‘k’ should be removed and the size should be converted to an equivalent of ‘megabytes’.

# %%
#convert all apps size in mb data and drop some sign for coverting it into float data type
df1['Size'] = df1['Size'].apply(lambda x: str(x).replace('Varies with device', '20') if 'Varies with device' in str(x) else x)
df1['Size'] = df1['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
df1['Size'] = df1['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
df1['Size'] = df1['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
df1['Size'] = df1['Size'].apply(lambda x: float(x))

# %% [markdown]
# Since, size of the applications present in the datset are in MB and KB. Therefore, for ease in data processing, entire size column is converted to MB.

# %%
#Checking the data types of the columns after updating them to the appropriate format
df1.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                  float64
# Size                     float64
# Installs                 float64
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %% [markdown]
# ### Removing Duplicate Values

# %%
df1.shape
# Out:
# (10840, 13)

# %%
# dropping duplicates from the 'App' column
df1.drop_duplicates(subset = 'App', inplace = True)
df1.shape
# Out:
# (9659, 13)

# %% [markdown]
# ###What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations :-
#
# * Checked for outliers by plotting boxplots.
#
# * Replaced NaN values present in the rating column with the median.
#
# * Replaced NaN values present in categorical columns with the mode value of each respective column.
#
# * Converted the data type of columns to the appropriate format. Identified that certain columns contained numerical values but were marked as 'Object', requiring conversion to either integers or decimals for proper analysis.
#
# * Removed duplicate rows based on the "App" column, keeping only the first occurrence of each duplicate.
#
# Insights :-
#
# * Identifying and addressing outliers helps in ensuring data integrity and accurate analysis.
#
# * Replacing NaN values with appropriate statistical measures like median and mode helps in handling missing data effectively.
#
# * Converting columns to the appropriate data type enables accurate numerical analysis and enhances the reliability of insights drawn from the dataset
#
# * removing duplicate rows ensures that each app has a unique representation in the dataset, which is important for accurate analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#plotting category wise counts of apps
plt.figure(figsize=(14,7))
plt.xticks(rotation = 90)
plt.ylabel("Number of application")
plt.xlabel("Category")
plt.title("Count of applications for each Category")
sns.countplot(x ='Category',data =df1,order = df1["Category"].value_counts().sort_values().index)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart because it is an effective way to compare the number of applications across different categories, providing a clear visual representation of the frequency of each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart revealed that the categories "Family", "Game", and "Tools" have the highest number of applications, indicating their popularity and potentially higher competition within these categories.
# while "Beauty", "comics", and "Events" have far fewer apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact by informing developers and businesses about high-demand categories, allowing them to focus their efforts where user interest is high.
#
# However, high competition in these categories might lead to negative growth for new entrants who may struggle to gain

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# total app installs in each category of the play store
a = df1.groupby(['Category'])['Installs'].sum().sort_values()
a.plot.barh(figsize=(13,10))
plt.ylabel('App Categories', fontsize = 15)
plt.xlabel('Total app Installs', fontsize = 15)
plt.xticks()
plt.title('Total app installs in each category', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Total app installs in each category')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart because it effectively visualizes the total app installs across different categories, making it easy to compare their popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This tells us the category of apps that has the maximum number of installs.
#
#  The " Game " and " Communication and Tools " categories has the highest number of installs compared to other categories of apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help target app development and marketing efforts towards categories with high installs, like Games.
#
#  However, focusing solely on popular categories might neglect potential growth opportunities in less popular categories, which could negatively impact overall business diversity.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#ratio of number of Paid apps and Free apps
data = df1['Type'].value_counts()
labels = ['Free','Paid']

# create pie chart
plt.figure(figsize=(6,7))
explode=(0.01,0.1)
plt.pie(data, labels = labels, autopct='%.2f%%',explode=explode,textprops={'fontsize': 15})
plt.title('Distribution of Paid and Free apps',size=15)
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the pie chart because it effectively shows the proportion of free versus paid apps, making the distribution easy to understand at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graph we can see that 92% of apps in google play store are free and 8%are paid.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can guide strategies for app monetization, highlighting the potential for ad revenue or in-app purchases in free apps. However, it also indicates a highly competitive market for free apps, which could make it challenging to stand out.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#creating a new dataframe having only paid type apps
paid_df = df1[df1['Type']=='Paid']

#category wise count of paid type apps
paid_df.groupby('Category')['Type'].count()
# Out:
# Category
# ART_AND_DESIGN           3
# AUTO_AND_VEHICLES        3
# BOOKS_AND_REFERENCE     28
# BUSINESS                12
# COMMUNICATION           27
# DATING                   6
# EDUCATION                4
# ENTERTAINMENT            2
# EVENTS                   1
# FAMILY                 183
# FINANCE                 17
# FOOD_AND_DRINK           2
# GAME                    82
# HEALTH_AND_FITNESS      15
# LIBRARIES_AND_DEMO       1
# LIFESTYLE               19
# MAPS_AND_NAVIGATION      5
# MEDICAL                 83
# NEWS_AND_MAGAZINES       2
# PARENTING                2
# PERSONALIZATION         81
# PHOTOGRAPHY             19
# PRODUCTIVITY            28
# SHOPPING                 2
# SOCIAL                   3
# SPORTS                  24
# TOOLS                   78
# TRAVEL_AND_LOCAL        12
# VIDEO_PLAYERS            4
# WEATHER                  8
# Name: Type, dtype: int64

# %%
#Plotting Category wise Paid apps
plt.figure(figsize=(14,7))
plt.plot(paid_df.groupby('Category')['Type'].count(),marker='o')
plt.title('Category wise Paid apps')
plt.xticks(rotation = 90)
plt.xlabel('Categories')
plt.ylabel('Number of Paid Apps')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the line chart because it effectively illustrates the distribution and trends in the number of paid apps across different categories, making it easy to identify which categories have more or fewer paid apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight is that the Family category has the highest number of paid apps (183), followed by categories like Medical (83), Game (82), and Personalization (81). Categories such as Events, Entertainment, and Libraries and Demo have the fewest paid apps, with only 1-2 each.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help businesses focus on categories with a higher number of paid apps, for potential revenue growth. However, it also suggests that categories with fewer paid apps might either represent untapped opportunities or lack demand. Focusing on low-demand categories without further market research could lead to negative growth due to insufficient user interest.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5

plt.figure(figsize=(14,9))

val=sns.boxplot(x=df1["Category"], y=df1["Rating"])
val.axhline(df1['Rating'].mean(),ls="-",color="red")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the box plot because it effectively shows the distribution of ratings across different categories, highlighting the median, quartiles, and outliers, which helps in understanding the overall rating trends and variability within each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight is that most categories have a median rating around 4.0 to 4.5. Categories like Health and Fitness, Books and Reference, and Weather show a higher variability in ratings, with some lower outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help identify categories with consistently high ratings, indicating user satisfaction, which can guide app development and marketing strategies. Conversely, categories with high variability and low outliers may need quality improvements to avoid negative growth due to user dissatisfaction.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Distribution of App Ratings in Play Store Data
# Set up the visualisation settings
sns.set(style='whitegrid')

# Plot distribution of App Ratings
plt.figure(figsize=(10, 5))
plt.title('Distribution of App Ratings',size=20)
sns.histplot(df1['Rating'], bins=50, kde=True)
plt.xlabel('Rating',size=15)
plt.xlim([1, 5])
plt.ylabel('Frequency',size=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the distplot because it effectively shows the distribution of app ratings and their frequency, providing a clear visual representation of how ratings are spread and highlighting the most common rating ranges.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight is that the majority of apps have high ratings between 4.0 and 4.5, with the highest frequency peaking around 4.3. Ratings below 4.0 have significantly lower frequencies, indicating fewer low-rated apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help developers focus on maintaining high-quality standards to achieve ratings between 4.0 and 4.5, which are most common and popular among users. Ignoring the few low-rated apps without addressing their issues could lead to negative reviews and impact the overall perception, potentially hindering growth.

# %% [markdown]
# #### Chart - 7

# %%
#installs per content rating of apps
df1.groupby('Content Rating')['Installs'].sum().sort_values(ascending=False).reset_index()
# Out:
#     Content Rating      Installs
# 0         Everyone  5.217935e+10
# 1             Teen  1.648728e+10
# 2     Everyone 10+  4.016272e+09
# 3       Mature 17+  2.437987e+09
# 4  Adults only 18+  2.000000e+06
# 5          Unrated  5.050000e+04

# %%
# Chart - 7 visualization code
df1.groupby('Content Rating')['Installs'].sum().plot(kind='bar')
plt.ylabel('Installs',size=15)
plt.title('installs per content rating of apps',size=20)
# Out:
# Text(0.5, 1.0, 'installs per content rating of apps')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart because it clearly displays the number of installs for different content ratings, making it easy to compare the popularity of apps across these categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight is that apps rated for Everyone and Teen have the highest number of installs, whereas Unrated and Adult Only 18+ apps have significantly fewer installs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can guide developers to target content ratings that attract more users, like Everyone and Teen, potentially increasing app downloads and revenue. However, focusing exclusively on popular content ratings might neglect niche markets, possibly leading to missed opportunities in those segments.

# %% [markdown]
# #### Chart - 8

# %%
#dataset on rating, reviews,installs,size and price
df=df1[["Rating","Reviews","Installs","Size","Price"]]
df.corr()
# Out:
#             Rating   Reviews  Installs      Size     Price
# Rating    1.000000  0.050207  0.034307  0.043682 -0.018662
# Reviews   0.050207  1.000000  0.625165  0.084776 -0.007598
# Installs  0.034307  0.625165  1.000000  0.056674 -0.009405
# Size      0.043682  0.084776  0.056674  1.000000 -0.022301
# Price    -0.018662 -0.007598 -0.009405 -0.022301  1.000000

# %%
# Chart - 8 visualization code
#Plotting a heatmap
fig, axes = plt.subplots(figsize=(8, 8))
plt.title("co-relations of variables using a heatmap", fontsize=16)
sns.heatmap(df.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the heatmap because it effectively visualizes the correlation matrix, highlighting the strength and direction of relationships between multiple numerical variables in a compact, easy-to-interpret manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap reveals that there is a strong positive correlation between the number of reviews and the number of installs **(0.63)**. Other variables like rating, size, and price show weak correlations with each other.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can help create a positive business impact by focusing on strategies to increase the number of reviews, which is strongly correlated with installs, potentially driving more downloads. There are no insights indicating negative growth, as no strong negative correlations are observed.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Convert 'Last Updated' column to datetime type
df1['Last Updated'] = pd.to_datetime(df1['Last Updated'])

# Extract year from 'Last Updated' column
df1['Updated_Year'] = df1['Last Updated'].dt.year

# Count the number of updates for each year
updates_per_year = df1['Updated_Year'].value_counts().sort_index()

# %%
# Plotting the line chart
plt.figure(figsize=(14, 7))
plt.plot(updates_per_year.index, updates_per_year.values, marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Number of Updates')
plt.title('Number of Updates Over the Years')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is a line chart that represents the number of updates over the years. A line chart is an ideal choice for this type of data because it clearly shows trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There was a steady but slow increase in the number of updates from 2010 to 2015.
#
# From 2015 onwards, the number of updates started to increase more noticeably.
#
# A significant spike in the number of updates is observed from 2017 to 2018, indicating a substantial increase in update activity during this period.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The significant increase in updates from 2017 to 2018 suggests a growing trend in app development and maintenance. This could indicate that developers are increasingly focusing on improving their apps, fixing bugs, and adding new features, which is essential for user satisfaction and retention.

# %% [markdown]
# #### Now we do EDA on another given dataset
# #### DATASET-2

# %%
#first five observations
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#Basic info of dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
#Descriptive statistics
df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
# Dataset Columns
df2.columns.tolist()
# Out:
# ['App',
#  'Translated_Review',
#  'Sentiment',
#  'Sentiment_Polarity',
#  'Sentiment_Subjectivity']

# %%
#Shape of dataset
df2.shape
# Out:
# (64295, 5)

# %% [markdown]
# **Let us first define what information the columns contain based on our inspection.**
#
# user_reviews dataframe has 64295 rows and 5 columns. The 5 columns are identified as follows:
#
# * **App**: Contains the name of the app with a short description (optional).
#
# * **Translated_Review**: It contains the English translation of the review dropped by the user of the app.
#
# * **Sentiment**: It gives the attitude/emotion of the writer. It can be ‘Positive’, ‘Negative’, or ‘Neutral’.
#
# * **Sentiment_Polarity**: It gives the polarity of the review. Its range is [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’.
#
# * **Sentiment_Subjectivity**: This value gives how close a reviewers opinion is to the opinion of the general public. Its range is [0,1]. Higher the subjectivity, closer is the reviewers opinion to the opinion of the general public, and lower subjectivity indicates the review is more of a factual information.

# %% [markdown]
# **Understanding features**
#
# >**Sentiment** : A view or opinion that is held or expressed. It can be
# Positive, Negative or Neutral.
#
# >**Sentiment Polarity** :Sentiment polarity for an element defines the orientation of the expressed sentiment, i.e., it determines if the text expresses the positive, negative or neutral sentiment of the user about the entity in consideration. The polarity score is a float within the range [-1.0, 1.0].
#
# >**Sentiment Subjectivity** : Subjectivity quantifies the amount of personal opinion and factual information contained in the text. The higher subjectivity means that the text contains personal opinion rather than factual information. Subjectivity lies between [0.0,1.0]. 0.0 is very objective and 1.0 is very subjective.

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ![sentiment_analysis_lstm.png](data:image/png;base64,...)

# %% [markdown]
# ###Loking for and handling NaN/Null/Missing Values

# %%
#check null values present in each column
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
#Null Value percentage
null_percentage = 100*df2['Sentiment'].isnull().sum()/df2.shape[0]
null_percentage
# Out:
# 41.78085387666226

# %% [markdown]
# **Four out of five columns contain near about 41% null values, So we drop them because it has no use.**

# %%
#dropping null values
df2.dropna(inplace=True)

# %%
#let's take a look at shape after removing null values.
df2.shape
# Out:
# (37427, 5)

# %% [markdown]
# ###Checking for outliers

# %%
#checking outlier in Sentiment_Polarity column
print(df2['Sentiment_Polarity'].min())
print(df2['Sentiment_Polarity'].max())
# Out:
# -1.0
# 1.0

# %%
#checking outlier in Sentiment_Subjectivity column
print(df2['Sentiment_Subjectivity'].min())
print(df2['Sentiment_Polarity'].max())
# Out:
# 0.0
# 1.0

# %%
#we can check outlier using boxplot also.
df2.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Values of sentiment polarity lies between -1 to 1, so there is no any outlier is present.
#
# Values of sentiment subjectivity lies between 0 to 1, so there is no any outlier is present.

# %% [markdown]
# ### Merging df1 and df2 on Apps

# %%
#first me mearge dataframes
merged_df =df1.merge(df2, on='App')

# %%
#first five rows of merged dataframe
merged_df.head()
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0  500000.0  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0  500000.0  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0  500000.0  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0  500000.0  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9    967.0  14.0  500000.0  Free
#
#    Price Content Rating                     Genres Last Updated Current Ver  \
# 0    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 1    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 2    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 3    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
# 4    0.0       Everyone  Art & Design;Pretend Play   2018-01-15       2.0.0
#
#     Android Ver  Updated_Year  \
# ...

# %%
#shape of merged dataframe.
merged_df.shape
# Out:
# (35929, 18)

# %% [markdown]
# On observing merged dataframe we found that there are many duplicate rows are present, So we have to remove those duplicate rows.

# %%
#removing duplicates except the first occurrence
merged_df.drop_duplicates(keep='first', inplace=True)

# %%
merged_df.shape
# Out:
# (28250, 18)

# %% [markdown]
# ###Data Visualization on User Reviews Data set:

# %% [markdown]
# ### Creating various graphical representations to understand the data better

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#sentiment percentage
plt.figure(figsize=(8,6))
plt.title("sentiment percentege",fontsize = 16)
plt.pie(merged_df.Sentiment.value_counts(), labels=merged_df.Sentiment.value_counts().index,autopct='%1.1f%%',startangle=90,explode=(0,0.1,0))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be seen from the above plot that the number of positive reviews are way higher than negative and neutral ones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above plot that the number of positive reviews(64%) are way higher than negative(22%) and neutral ones.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#plotting boxplot
sns.boxplot(x=merged_df['Sentiment'], y =merged_df['Sentiment_Polarity'])
# Out:
# <Axes: xlabel='Sentiment', ylabel='Sentiment_Polarity'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen to clearly display the distribution, central tendency, and variability of sentiment polarity across negative, neutral, and positive categories, while also highlighting any outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Negative sentiment shows a significant number of strong negative outliers, neutral sentiment is tightly clustered around zero, and positive sentiment has higher variability but generally positive feedback.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights help identify key areas for improvement and enhancement, potentially boosting user satisfaction. However, unresolved negative outliers could harm the app's reputation and block the growth.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#plotting boxplot
sns.boxplot(x=merged_df['Sentiment'], y=merged_df['Sentiment_Subjectivity'])
# Out:
# <Axes: xlabel='Sentiment', ylabel='Sentiment_Subjectivity'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen to show how the sentiment subjectivity scores are spread out for negative, neutral, and positive sentiments, including any outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Negative and positive sentiments have similar distributions with some variability, while neutral sentiment is highly clustered around a few values with many outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding how subjective the reviews are can help in identifying the nature of feedback. Consistent patterns in neutral reviews indicate stable, objective feedback, which is good for making informed improvements. High subjectivity in negative reviews needs to be addressed to avoid negative growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#histogram based on subjectivity
plt.figure(figsize=(10,6))
plt.hist(merged_df[merged_df['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'],color = "skyblue")
plt.xlabel("Subjectivity",fontsize=16)
plt.title("Distribution of Subjectivity",fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it is used to summarize discrete or continuous data that are measured on an interval scale. It is often used to illustrate the major features of the distribution of the data in a convenient form.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that maximum number of users give reviews to the applications, according to their experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above histogram insight that the most people rate apps on basis of their own experience with the apps.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
#histograme based on polarity
plt.figure(figsize=(10,6))
plt.hist(merged_df[merged_df['Sentiment_Polarity'].notnull()]['Sentiment_Polarity'],color = "skyblue")
plt.xlabel("Polarity",fontsize=16)
plt.title("Distribution of polarity",fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it is used to summarize discrete or continuous data that are measured on an interval scale. It is often used to illustrate the major features of the distribution of the data in a convenient form.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be seen that the maximum number of sentiment polarity lies between 0.0 to 0.50.it mins most people have positive sentiment

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The maximum number of sentiment polarity lies between 0.0 to 0.50.it mins most people have positive sentiment which is good for business.

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code
plt.figure(figsize=(14,7))
sns.scatterplot(data=merged_df,x='Sentiment_Subjectivity', y='Sentiment_Polarity',hue="Sentiment")
plt.title("Does sentiment_subjectivity proportional to sentiment_polarity",fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because Scatter plots are used to plot data points on a horizontal and a vertical axis in an attempt to show how much one variable is affected by another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above scatter plot it can be concluded that sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# As per the above analysis FAMILY category has very much scope because it has all age group people. second category is GAME that has also scope.
#
# Eventhough apps from the categories like FAMILY, SOCIAL, COMMUNICATION and ENTERTAINMENT of having the highest amount of installs, rating and reviews are reflecting the current trend of Android users, they are not even appearing as category in the top 5 most expensive apps in the store (which are mostly from FINANCE and LIFESTYLE). As a conclsuion, we learnt that the current trend in the Android market are mostly from these categories which either assisting, communicating or entertaining apps.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **1.Rating**
#
# *   Most of the apps have rating between 4 and 5.
# *   Most numbers of apps are rated at 4.3.
# *   All categories of apps have more than 4 average rating.
#
# **2.Size**
#
# *   Maximum number of applications present in the dataset are of small size.
#
# **3.Installs**
#
# *   Majority of the apps come into these three categories, Family, Game, and Tools.
# *   Maximum number of apps present in google play store come under Family, Game and tools but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Game, Communication, Productivity and Social.
# *   Subway Surfers, Facebook, Messenger and Google Drive are the most installed apps.
#
# **4.Type(Free/Paid)**
#
# *   About 92% apps are free and 8% apps are of paid type.
# *   The category ‘Family’ has the highest number of paid apps.
# *   The category ‘Family’ has the highest number of paid apps.
# *   The app “I’m Rich — Trump Edition” from the category ‘Lifestyle’ is the most costly app priced at $400
#
# **5.Content Rating**
#
# *   Content having Everyone only has most installs, while unrated and Adults only 18+ have less installs.
#
# **6.Reviews**
#
# *   Number of installs is positively correlated with reviews with correlation 0.64 Sentiment Analysis.
#
# **7.Sentiment**
#
# *   Most of the reviews are of Positive Sentiment, while Negative and Neutral have low number of reviews.
#
# **8.Sentiment Polarity / Sentiment Subjectivity**
#
# *   Collection of reviews shows a wide range of subjectivity and most of the reviews fall in [-0.50,0.75] polarity scale implying that the extremely negative or positive sentiments are significantly low.
#
# *   Most of the reviews show a mid-range of negative and positive sentiments.
#
# *   Sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low
#
# *   Sentiment Polarity is not highly correlated with Sentiment Subjectivity.
#
# The analysis of Google Play Store application aided to build most reliable and more interactive applications. This would be very useful for app developers to build an application focussed on certain discussed category in this analysis. This analysis will definitely help in building the application with precise and accurate objectives.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
